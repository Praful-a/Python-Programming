# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Praful\Desktop\Pandas\Data\survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv(r'C:\Users\Praful\Desktop\Pandas\Data\survey_results_schema.csv', index_col="Column")

# %%
df.head(1)
# Out:
#                                         MainBranch Hobbyist OpenSourcer  \
# Respondent
# 1           I am a student who is learning to code      Yes       Never
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
#
#                                         Employment         Country Student  \
# Respondent
# 1           Not employed, and not looking for work  United Kingdom      No
#
#                               EdLevel UndergradMajor  \
# Respondent
# 1           Primary/elementary school            NaN
#
#                                                      EduOther  ...  \
# Respondent                                                     ...
# 1           Taught yourself a new language, framework, or ...  ...
#
#                                       WelcomeChange  \
# Respondent
# 1           Just as welcome now as I felt last year
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 1           Tech articles written by other developers;Indu...  14.0    Man
#
#            Trans                Sexuality Ethnicity Dependents  \
# Respondent
# 1             No  Straight / Heterosexual       NaN         No
#
#                      SurveyLength                  SurveyEase
# Respondent
# 1           Appropriate in length  Neither easy nor difficult
#
# [1 rows x 84 columns]

# %%
schema_df.head()
# Out:
#                                                   QuestionText
# Column
# Respondent   Randomized respondent ID number (not in order ...
# MainBranch   Which of the following options best describes ...
# Hobbyist                               Do you code as a hobby?
# OpenSourcer        How often do you contribute to open source?
# OpenSource   How do you feel about the quality of open sour...

# %%
df['ConvertedComp'].head(15)
# Out:
# Respondent
# 1          NaN
# 2          NaN
# 3       8820.0
# 4      61000.0
# 5          NaN
# 6     366420.0
# 7          NaN
# 8          NaN
# 9      95179.0
# 10     13293.0
# 11         NaN
# 12         NaN
# 13     90000.0
# 14     57060.0
# 15         NaN
# Name: ConvertedComp, dtype: float64

# %%
df['ConvertedComp'].median()
# Out:
# 57287.0

# %%
df.median()
# Out:
# CompTotal        62000.0
# ConvertedComp    57287.0
# WorkWeekHrs         40.0
# CodeRevHrs           4.0
# Age                 29.0
# dtype: float64

# %%
df.describe()
# Out:
#           CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs           Age
# count  5.594500e+04   5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   5.519014e+11   1.271107e+05     42.127197      5.084308     30.336699
# std    7.331926e+13   2.841523e+05     37.287610      5.513931      9.178390
# min    0.000000e+00   0.000000e+00      1.000000      0.000000      1.000000
# 25%    2.000000e+04   2.577750e+04     40.000000      2.000000     24.000000
# 50%    6.200000e+04   5.728700e+04     40.000000      4.000000     29.000000
# 75%    1.200000e+05   1.000000e+05     44.750000      6.000000     35.000000
# max    1.000000e+16   2.000000e+06   4850.000000     99.000000     99.000000

# %%
df['ConvertedComp'].count()
# Out:
# 55823

# %%
df['Hobbyist'].head(10)
# Out:
# Respondent
# 1     Yes
# 2      No
# 3     Yes
# 4      No
# 5     Yes
# 6     Yes
# 7      No
# 8     Yes
# 9     Yes
# 10    Yes
# Name: Hobbyist, dtype: object

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df['SocialMedia'].head(5)
# Out:
# Respondent
# 1      Twitter
# 2    Instagram
# 3       Reddit
# 4       Reddit
# 5     Facebook
# Name: SocialMedia, dtype: object

# %%
schema_df.loc['SocialMedia']
# Out:
# QuestionText    What social media site do you use the most?
# Name: SocialMedia, dtype: object

# %%
df['SocialMedia'].value_counts()
# Out:
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: SocialMedia, dtype: int64

# %%
df['SocialMedia'].value_counts(normalize=True)
# Out:
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: SocialMedia, dtype: float64

# %%
df['Country'].value_counts().head(10)
# Out:
# United States     20949
# India              9061
# Germany            5866
# United Kingdom     5737
# Canada             3395
# France             2391
# Brazil             1948
# Poland             1922
# Australia          1903
# Netherlands        1852
# Name: Country, dtype: int64

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('India')
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
# 68                  I am a developer by profession      Yes
# 75                  I am a developer by profession      Yes
# 78                  I am a developer by profession       No
# 83                  I am a developer by profession      Yes
# 89          I am a student who is learning to code      Yes
# 90                  I am a developer by profession      Yes
# 99          I am a student who is learning to code      Yes
# 104                 I am a developer by profession      Yes
# 121         I am a student who is learning to code      Yes
# 124                 I am a developer by profession      Yes
# 140                 I am a developer by profession      Yes
# 169                 I am a developer by profession       No
# 174                 I am a developer by profession      Yes
# 176                 I am a developer by profession      Yes
# 178                 I am a developer by profession      Yes
# 220                 I am a developer by profession       No
# 238                 I am a developer by profession      Yes
# 239                 I am a developer by profession      Yes
# 242                 I am a developer by profession      Yes
# 263                 I am a developer by profession       No
# 271                 I am a developer by profession      Yes
# 288                 I am a developer by profession      Yes
# 291                 I am a developer by profession       No
# 343                 I am a developer by profession      Yes
# 344                 I am a developer by profession      Yes
# ...                                            ...      ...
# 88843               I am a developer by profession      Yes
# 88856               I am a developer by profession      Yes
# 88869               I am a developer by profession       No
# 88872               I am a developer by profession      Yes
# 14444                                          NaN       No
# 20000                                          NaN      Yes
# 20567                                          NaN      Yes
# 20892                                          NaN       No
# 21826                                          NaN      Yes
# 24606                                          NaN      Yes
# 25114                                          NaN      Yes
# 26419                                          NaN       No
# 27229                                          NaN      Yes
# 35010                                          NaN      Yes
# 40151                                          NaN       No
# 40898                                          NaN      Yes
# 42599                                          NaN       No
# 43809                                          NaN      Yes
# 50685                                          NaN       No
# 60133                                          NaN      Yes
# 63972                                          NaN      Yes
# 65988                                          NaN      Yes
# 71874                                          NaN      Yes
# 75103                                          NaN      Yes
# 76822                                          NaN       No
# 77339                                          NaN      Yes
# 79795                                          NaN      Yes
# 83862                                          NaN      Yes
# 84299                                          NaN      Yes
# 86012                                          NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 8                                     Less than once per year
# 10                                 Once a month or more often
# 15                                                      Never
# 50                                 Once a month or more often
# 65                                                      Never
# 68          Less than once a month but more than once per ...
# 75                                                      Never
# 78          Less than once a month but more than once per ...
# 83          Less than once a month but more than once per ...
# 89                                                      Never
# 90          Less than once a month but more than once per ...
# 99                                    Less than once per year
# 104                                                     Never
# 121         Less than once a month but more than once per ...
# 124                                Once a month or more often
# 140                                   Less than once per year
# 169                                   Less than once per year
# 174         Less than once a month but more than once per ...
# 176         Less than once a month but more than once per ...
# 178                                Once a month or more often
# 220                                                     Never
# 238         Less than once a month but more than once per ...
# 239                                   Less than once per year
# 242                                Once a month or more often
# 263                                                     Never
# 271                                                     Never
# 288                                   Less than once per year
# 291                                                     Never
# 343                                   Less than once per year
# 344         Less than once a month but more than once per ...
# ...                                                       ...
# 88843                                                   Never
# 88856                                                   Never
# 88869                                                   Never
# 88872       Less than once a month but more than once per ...
# 14444                                 Less than once per year
# 20000                                 Less than once per year
# 20567       Less than once a month but more than once per ...
# 20892                                 Less than once per year
# 21826                                 Less than once per year
# 24606                              Once a month or more often
# 25114                                                   Never
# 26419                                 Less than once per year
# 27229                                                   Never
# 35010                                                   Never
# 40151                                 Less than once per year
# 40898                                                   Never
# 42599                              Once a month or more often
# 43809                              Once a month or more often
# 50685                              Once a month or more often
# 60133                                                   Never
# 63972                                                   Never
# 65988                                                   Never
# 71874                                                   Never
# 75103                                                   Never
# 76822       Less than once a month but more than once per ...
# 77339                                 Less than once per year
# 79795       Less than once a month but more than once per ...
# 83862                              Once a month or more often
# 84299                                                   Never
# 86012                              Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 8           OSS is, on average, of HIGHER quality than pro...
# 10          OSS is, on average, of HIGHER quality than pro...
# 15          OSS is, on average, of HIGHER quality than pro...
# 50          OSS is, on average, of LOWER quality than prop...
# 65                                                        NaN
# 68          OSS is, on average, of LOWER quality than prop...
# 75          OSS is, on average, of HIGHER quality than pro...
# 78          The quality of OSS and closed source software ...
# 83          OSS is, on average, of HIGHER quality than pro...
# 89          OSS is, on average, of HIGHER quality than pro...
# 90          The quality of OSS and closed source software ...
# 99          The quality of OSS and closed source software ...
# 104         OSS is, on average, of LOWER quality than prop...
# 121         OSS is, on average, of HIGHER quality than pro...
# 124         OSS is, on average, of HIGHER quality than pro...
# 140         OSS is, on average, of HIGHER quality than pro...
# 169         The quality of OSS and closed source software ...
# 174         OSS is, on average, of HIGHER quality than pro...
# 176         OSS is, on average, of HIGHER quality than pro...
# 178         The quality of OSS and closed source software ...
# 220         The quality of OSS and closed source software ...
# 238         OSS is, on average, of HIGHER quality than pro...
# 239         The quality of OSS and closed source software ...
# 242         OSS is, on average, of HIGHER quality than pro...
# 263         The quality of OSS and closed source software ...
# 271         OSS is, on average, of HIGHER quality than pro...
# 288         OSS is, on average, of HIGHER quality than pro...
# 291         The quality of OSS and closed source software ...
# 343         The quality of OSS and closed source software ...
# 344         The quality of OSS and closed source software ...
# ...                                                       ...
# 88843       OSS is, on average, of HIGHER quality than pro...
# 88856       OSS is, on average, of HIGHER quality than pro...
# 88869       OSS is, on average, of LOWER quality than prop...
# 88872       OSS is, on average, of HIGHER quality than pro...
# 14444       The quality of OSS and closed source software ...
# 20000       OSS is, on average, of HIGHER quality than pro...
# 20567       OSS is, on average, of HIGHER quality than pro...
# 20892       The quality of OSS and closed source software ...
# 21826       The quality of OSS and closed source software ...
# 24606       OSS is, on average, of HIGHER quality than pro...
# 25114       The quality of OSS and closed source software ...
# 26419       The quality of OSS and closed source software ...
# 27229       The quality of OSS and closed source software ...
# 35010       The quality of OSS and closed source software ...
# 40151       OSS is, on average, of HIGHER quality than pro...
# 40898       OSS is, on average, of HIGHER quality than pro...
# 42599       The quality of OSS and closed source software ...
# 43809       OSS is, on average, of HIGHER quality than pro...
# 50685       OSS is, on average, of LOWER quality than prop...
# 60133       OSS is, on average, of HIGHER quality than pro...
# 63972       OSS is, on average, of LOWER quality than prop...
# 65988       OSS is, on average, of LOWER quality than prop...
# 71874       OSS is, on average, of HIGHER quality than pro...
# 75103       OSS is, on average, of HIGHER quality than pro...
# 76822       OSS is, on average, of HIGHER quality than pro...
# 77339       OSS is, on average, of HIGHER quality than pro...
# 79795       OSS is, on average, of HIGHER quality than pro...
# 83862       OSS is, on average, of HIGHER quality than pro...
# 84299       The quality of OSS and closed source software ...
# 86012       OSS is, on average, of HIGHER quality than pro...
#
#                                                    Employment Country  \
# Respondent
# 8                          Not employed, but looking for work   India
# 10                                         Employed full-time   India
# 15                         Not employed, but looking for work   India
# 50                                         Employed full-time   India
# 65                                         Employed full-time   India
# 68                                         Employed full-time   India
# 75                                         Employed full-time   India
# 78                                         Employed full-time   India
# 83                                         Employed full-time   India
# 89                     Not employed, and not looking for work   India
# 90                                         Employed full-time   India
# 99                                         Employed part-time   India
# 104                                        Employed full-time   India
# 121         Independent contractor, freelancer, or self-em...   India
# 124                                        Employed full-time   India
# 140                                        Employed full-time   India
# 169                                                       NaN   India
# 174                                        Employed full-time   India
# 176                                        Employed full-time   India
# 178         Independent contractor, freelancer, or self-em...   India
# 220                                        Employed full-time   India
# 238                                        Employed full-time   India
# 239                                        Employed full-time   India
# 242                                        Employed full-time   India
# 263         Independent contractor, freelancer, or self-em...   India
# 271                                        Employed full-time   India
# 288                                        Employed full-time   India
# 291                                        Employed full-time   India
# 343                                        Employed full-time   India
# 344                                        Employed full-time   India
# ...                                                       ...     ...
# 88843                                      Employed full-time   India
# 88856                                      Employed full-time   India
# 88869                                      Employed full-time   India
# 88872                                      Employed full-time   India
# 14444       Independent contractor, freelancer, or self-em...   India
# 20000                                      Employed full-time   India
# 20567                  Not employed, and not looking for work   India
# 20892                                      Employed full-time   India
# 21826                                      Employed full-time   India
# 24606                                      Employed full-time   India
# 25114                                      Employed part-time   India
# 26419                      Not employed, but looking for work   India
# 27229                                      Employed full-time   India
# 35010                                                     NaN   India
# 40151                                                     NaN   India
# 40898                      Not employed, but looking for work   India
# 42599                                      Employed full-time   India
# 43809                                      Employed full-time   India
# 50685                                                 Retired   India
# 60133                                      Employed full-time   India
# 63972                                      Employed full-time   India
# 65988       Independent contractor, freelancer, or self-em...   India
# 71874       Independent contractor, freelancer, or self-em...   India
# 75103                                      Employed full-time   India
# 76822                                                     NaN   India
# 77339                                      Employed full-time   India
# 79795                                      Employed full-time   India
# 83862                                      Employed full-time   India
# 84299                                      Employed full-time   India
# 86012                                      Employed full-time   India
#
#                    Student                                            EdLevel  \
# Respondent
# 8                      NaN           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 10                      No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 15          Yes, full-time  Secondary school (e.g. American high school, G...
# 50                      No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 65                      No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 68                      No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 75          Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 78          Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 83                      No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 89                      No  Some college/university study without earning ...
# 90                      No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 99          Yes, full-time  Secondary school (e.g. American high school, G...
# 104         Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 121         Yes, full-time  Secondary school (e.g. American high school, G...
# 124                     No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 140                     No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 169         Yes, full-time        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 174                     No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 176                     No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 178         Yes, full-time                                                NaN
# 220         Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 238         Yes, part-time        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 239                     No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 242         Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 263                     No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 271                     No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 288         Yes, full-time        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 291         Yes, full-time        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 343                     No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 344         Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                    ...                                                ...
# 88843                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88856       Yes, full-time        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 88869                  NaN                                                NaN
# 88872                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 14444       Yes, full-time  Some college/university study without earning ...
# 20000       Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 20567       Yes, full-time        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 20892       Yes, part-time                                                NaN
# 21826       Yes, full-time                                                NaN
# 24606                  NaN                                   Associate degree
# 25114       Yes, part-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 26419                   No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 27229                   No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 35010                   No                          Primary/elementary school
# 40151                   No  Secondary school (e.g. American high school, G...
# 40898                  NaN           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 42599       Yes, full-time        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 43809                   No                                                NaN
# 50685                  NaN             I never completed any formal education
# 60133                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 63972                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 65988                  NaN  Some college/university study without earning ...
# 71874                   No                                                NaN
# 75103                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 76822                  NaN                 Professional degree (JD, MD, etc.)
# 77339       Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 79795                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 83862       Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 84299       Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 86012                   No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
#
#                                                UndergradMajor  \
# Respondent
# 8           Computer science, computer engineering, or sof...
# 10                                                        NaN
# 15                                                        NaN
# 50          Another engineering discipline (ex. civil, ele...
# 65          Information systems, information technology, o...
# 68                              Web development or web design
# 75          Computer science, computer engineering, or sof...
# 78          Computer science, computer engineering, or sof...
# 83                              Web development or web design
# 89          Computer science, computer engineering, or sof...
# 90          Computer science, computer engineering, or sof...
# 99                                                        NaN
# 104         Computer science, computer engineering, or sof...
# 121                                                       NaN
# 124         Computer science, computer engineering, or sof...
# 140         Computer science, computer engineering, or sof...
# 169         Computer science, computer engineering, or sof...
# 174         Computer science, computer engineering, or sof...
# 176         Computer science, computer engineering, or sof...
# 178         Computer science, computer engineering, or sof...
# 220         A business discipline (ex. accounting, finance...
# 238         Computer science, computer engineering, or sof...
# 239         Computer science, computer engineering, or sof...
# 242         Computer science, computer engineering, or sof...
# 263         Computer science, computer engineering, or sof...
# 271                             Web development or web design
# 288         Computer science, computer engineering, or sof...
# 291         Computer science, computer engineering, or sof...
# 343         Computer science, computer engineering, or sof...
# 344         Another engineering discipline (ex. civil, ele...
# ...                                                       ...
# 88843       Computer science, computer engineering, or sof...
# 88856                           Web development or web design
# 88869                                                     NaN
# 88872       Computer science, computer engineering, or sof...
# 14444                                                     NaN
# 20000       Information systems, information technology, o...
# 20567       A natural science (ex. biology, chemistry, phy...
# 20892       Another engineering discipline (ex. civil, ele...
# 21826                           Web development or web design
# 24606                                                     NaN
# 25114                               Mathematics or statistics
# 26419       Information systems, information technology, o...
# 27229       Information systems, information technology, o...
# 35010                                                     NaN
# 40151                                                     NaN
# 40898       Computer science, computer engineering, or sof...
# 42599                                                     NaN
# 43809       Computer science, computer engineering, or sof...
# 50685                                                     NaN
# 60133       Computer science, computer engineering, or sof...
# 63972       Computer science, computer engineering, or sof...
# 65988       Computer science, computer engineering, or sof...
# 71874                                                     NaN
# 75103       Computer science, computer engineering, or sof...
# 76822       A health science (ex. nursing, pharmacy, radio...
# 77339       Another engineering discipline (ex. civil, ele...
# 79795       Computer science, computer engineering, or sof...
# 83862                                                     NaN
# 84299                           Web development or web design
# 86012       Another engineering discipline (ex. civil, ele...
#
#                                                      EduOther  ...  \
# Respondent                                                     ...
# 8           Taught yourself a new language, framework, or ...  ...
# 10                                                        NaN  ...
# 15          Taken an online course in programming or softw...  ...
# 50          Received on-the-job training in software devel...  ...
# 65                                                        NaN  ...
# 68          Taken an online course in programming or softw...  ...
# 75          Taken an online course in programming or softw...  ...
# 78          Received on-the-job training in software devel...  ...
# 83          Taken an online course in programming or softw...  ...
# 89                                                        NaN  ...
# 90          Taught yourself a new language, framework, or ...  ...
# 99          Taken an online course in programming or softw...  ...
# 104         Taken a part-time in-person course in programm...  ...
# 121         Taken an online course in programming or softw...  ...
# 124                                                       NaN  ...
# 140         Taught yourself a new language, framework, or ...  ...
# 169                       Contributed to open source software  ...
# 174         Taken an online course in programming or softw...  ...
# 176         Completed an industry certification program (e...  ...
# 178         Taken an online course in programming or softw...  ...
# 220         Participated in a full-time developer training...  ...
# 238         Taken an online course in programming or softw...  ...
# 239         Taken an online course in programming or softw...  ...
# 242                                                       NaN  ...
# 263         Taken an online course in programming or softw...  ...
# 271         Taken an online course in programming or softw...  ...
# 288                                                       NaN  ...
# 291                                                       NaN  ...
# 343         Participated in online coding competitions (e....  ...
# 344         Received on-the-job training in software devel...  ...
# ...                                                       ...  ...
# 88843       Taken an online course in programming or softw...  ...
# 88856       Participated in online coding competitions (e....  ...
# 88869                                                     NaN  ...
# 88872       Taken an online course in programming or softw...  ...
# 14444                                                     NaN  ...
# 20000       Taken an online course in programming or softw...  ...
# 20567       Taken an online course in programming or softw...  ...
# 20892       Taught yourself a new language, framework, or ...  ...
# 21826       Taken an online course in programming or softw...  ...
# 24606       Taken a part-time in-person course in programm...  ...
# 25114                                                     NaN  ...
# 26419       Taken an online course in programming or softw...  ...
# 27229       Taught yourself a new language, framework, or ...  ...
# 35010       Participated in a full-time developer training...  ...
# 40151                                                     NaN  ...
# 40898       Taken an online course in programming or softw...  ...
# 42599                                                     NaN  ...
# 43809                                                     NaN  ...
# 50685                                                     NaN  ...
# 60133                                                     NaN  ...
# 63972       Taken an online course in programming or softw...  ...
# 65988       Taken an online course in programming or softw...  ...
# 71874                                                     NaN  ...
# 75103                                                     NaN  ...
# 76822                                                     NaN  ...
# 77339       Taken an online course in programming or softw...  ...
# 79795       Taken an online course in programming or softw...  ...
# 83862                             Participated in a hackathon  ...
# 84299       Taken an online course in programming or softw...  ...
# 86012       Taught yourself a new language, framework, or ...  ...
#
#                                                 WelcomeChange  \
# Respondent
# 8                       A lot more welcome now than last year
# 10                   Somewhat less welcome now than last year
# 15                    Just as welcome now as I felt last year
# 50                    Just as welcome now as I felt last year
# 65                      A lot more welcome now than last year
# 68                   Somewhat more welcome now than last year
# 75                    Just as welcome now as I felt last year
# 78                   Somewhat more welcome now than last year
# 83                    Just as welcome now as I felt last year
# 89                    Just as welcome now as I felt last year
# 90                    Just as welcome now as I felt last year
# 99                   Somewhat more welcome now than last year
# 104                   Just as welcome now as I felt last year
# 121                   Just as welcome now as I felt last year
# 124                     A lot more welcome now than last year
# 140                  Somewhat more welcome now than last year
# 169                     A lot more welcome now than last year
# 174                     A lot more welcome now than last year
# 176                   Just as welcome now as I felt last year
# 178                     A lot more welcome now than last year
# 220                  Somewhat more welcome now than last year
# 238                     A lot more welcome now than last year
# 239                     A lot more welcome now than last year
# 242                     A lot more welcome now than last year
# 263                   Just as welcome now as I felt last year
# 271                   Just as welcome now as I felt last year
# 288                   Just as welcome now as I felt last year
# 291                                                       NaN
# 343                  Somewhat more welcome now than last year
# 344                   Just as welcome now as I felt last year
# ...                                                       ...
# 88843                Somewhat more welcome now than last year
# 88856                Somewhat less welcome now than last year
# 88869                   A lot more welcome now than last year
# 88872                Somewhat more welcome now than last year
# 14444       Not applicable - I did not use Stack Overflow ...
# 20000                   A lot less welcome now than last year
# 20567                   A lot more welcome now than last year
# 20892                                                     NaN
# 21826                   A lot more welcome now than last year
# 24606                                                     NaN
# 25114                 Just as welcome now as I felt last year
# 26419                   A lot more welcome now than last year
# 27229                 Just as welcome now as I felt last year
# 35010                                                     NaN
# 40151                   A lot more welcome now than last year
# 40898                                                     NaN
# 42599       Not applicable - I did not use Stack Overflow ...
# 43809                Somewhat more welcome now than last year
# 50685                   A lot less welcome now than last year
# 60133                 Just as welcome now as I felt last year
# 63972                   A lot less welcome now than last year
# 65988                 Just as welcome now as I felt last year
# 71874                   A lot less welcome now than last year
# 75103                   A lot more welcome now than last year
# 76822                 Just as welcome now as I felt last year
# 77339       Not applicable - I did not use Stack Overflow ...
# 79795                Somewhat more welcome now than last year
# 83862                 Just as welcome now as I felt last year
# 84299                Somewhat more welcome now than last year
# 86012       Not applicable - I did not use Stack Overflow ...
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 8           Tech articles written by other developers;Indu...  24.0    Man
# 10          Tech articles written by other developers;Tech...   NaN    NaN
# 15          Tech articles written by other developers;Indu...  20.0    Man
# 50          Tech articles written by other developers;Tech...  23.0    Man
# 65                                                        NaN  21.0    Man
# 68          Tech articles written by other developers;Indu...  29.0    Man
# 75               Courses on technologies you're interested in  27.0  Woman
# 78          Tech articles written by other developers;Indu...  25.0    Man
# 83          Industry news about technologies you're intere...  22.0    Man
# 89          Tech articles written by other developers;Indu...   NaN    Man
# 90          Tech articles written by other developers;Indu...  25.0    Man
# 99          Industry news about technologies you're intere...  21.0    Man
# 104         Tech articles written by other developers;Indu...  29.0    Man
# 121         Tech articles written by other developers;Tech...  20.0    Man
# 124         Tech articles written by other developers;Cour...  27.0    Man
# 140         Tech articles written by other developers;Indu...  25.0    Man
# 169         Tech articles written by other developers;Indu...  32.0    Man
# 174         Industry news about technologies you're intere...  24.0    Man
# 176         Tech articles written by other developers;Indu...  31.0    Man
# 178         Tech articles written by other developers;Indu...  28.0    Man
# 220         Tech articles written by other developers;Indu...   NaN    Man
# 238         Tech articles written by other developers;Indu...  31.0    Man
# 239         Tech articles written by other developers;Tech...   NaN    NaN
# 242              Courses on technologies you're interested in  30.0    Man
# 263                                                       NaN  40.0    Man
# 271         Tech articles written by other developers;Tech...  24.0    Man
# 288         Tech articles written by other developers;Indu...   NaN    Man
# 291         Tech articles written by other developers;Tech...   NaN    Man
# 343         Tech articles written by other developers;Indu...  24.0  Woman
# 344         Tech articles written by other developers;Indu...  29.0    Man
# ...                                                       ...   ...    ...
# 88843       Industry news about technologies you're intere...  22.0    Man
# 88856       Tech articles written by other developers;Indu...   NaN    NaN
# 88869               Tech articles written by other developers  30.0    Man
# 88872       Tech articles written by other developers;Cour...   NaN    Man
# 14444       Tech articles written by other developers;Indu...   NaN    NaN
# 20000       Tech articles written by other developers;Indu...  28.0    Man
# 20567       Tech articles written by other developers;Indu...  22.0    Man
# 20892                                                     NaN  43.0    Man
# 21826               Tech articles written by other developers  22.0    Man
# 24606                                                     NaN   NaN    NaN
# 25114                     Tech meetups or events in your area  22.0    Man
# 26419       Tech articles written by other developers;Indu...  24.0  Woman
# 27229       Tech articles written by other developers;Indu...  34.0    Man
# 35010               Tech articles written by other developers   NaN    Man
# 40151                     Tech meetups or events in your area   NaN    Man
# 40898       Tech articles written by other developers;Tech...   NaN    Man
# 42599                                                     NaN  30.0    Man
# 43809       Tech articles written by other developers;Indu...   NaN  Woman
# 50685       Tech articles written by other developers;Indu...   NaN  Woman
# 60133       Tech articles written by other developers;Indu...  28.0    Man
# 63972       Tech articles written by other developers;Indu...   NaN    Man
# 65988       Tech articles written by other developers;Indu...  18.0    Man
# 71874                                                     NaN   NaN    NaN
# 75103       Tech articles written by other developers;Indu...   NaN    NaN
# 76822                                                     NaN   NaN    Man
# 77339       Tech articles written by other developers;Indu...   NaN    NaN
# 79795       Tech meetups or events in your area;Courses on...   NaN    Man
# 83862       Tech articles written by other developers;Indu...  24.0    Man
# 84299                                                     NaN   NaN    NaN
# 86012       Industry news about technologies you're intere...  24.0    Man
#
#            Trans                Sexuality    Ethnicity Dependents  \
# Respondent
# 8             No  Straight / Heterosexual          NaN        NaN
# 10           NaN                      NaN          NaN        Yes
# 15            No                      NaN          NaN        Yes
# 50            No                      NaN  South Asian         No
# 65            No                      NaN          NaN        Yes
# 68            No  Straight / Heterosexual  South Asian         No
# 75            No  Straight / Heterosexual          NaN         No
# 78            No                      NaN          NaN        Yes
# 83            No  Straight / Heterosexual  South Asian         No
# 89            No                 Bisexual   East Asian        Yes
# 90            No  Straight / Heterosexual          NaN        Yes
# 99            No  Straight / Heterosexual  South Asian         No
# 104           No  Straight / Heterosexual  South Asian        Yes
# 121           No  Straight / Heterosexual  South Asian         No
# 124           No                 Bisexual  South Asian        NaN
# 140           No  Straight / Heterosexual          NaN        NaN
# 169           No                      NaN   East Asian        Yes
# 174           No  Straight / Heterosexual  South Asian        Yes
# 176           No  Straight / Heterosexual   East Asian        Yes
# 178          NaN                 Bisexual  South Asian        Yes
# 220           No  Straight / Heterosexual          NaN        Yes
# 238           No  Straight / Heterosexual          NaN        Yes
# 239          NaN                      NaN          NaN        NaN
# 242          NaN                      NaN          NaN        Yes
# 263           No  Straight / Heterosexual  South Asian        Yes
# 271           No  Straight / Heterosexual  South Asian        Yes
# 288           No                 Bisexual  South Asian        Yes
# 291          NaN  Straight / Heterosexual  South Asian        NaN
# 343           No                      NaN          NaN        Yes
# 344           No  Straight / Heterosexual  South Asian        Yes
# ...          ...                      ...          ...        ...
# 88843         No  Straight / Heterosexual  South Asian        Yes
# 88856        NaN                      NaN          NaN        NaN
# 88869         No                      NaN  South Asian         No
# 88872         No                      NaN          NaN        Yes
# 14444         No                 Bisexual          NaN        NaN
# 20000         No                      NaN  South Asian        NaN
# 20567         No  Straight / Heterosexual  South Asian         No
# 20892         No                      NaN          NaN        Yes
# 21826         No                      NaN  South Asian        Yes
# 24606        NaN                      NaN          NaN        NaN
# 25114        NaN                      NaN          NaN        NaN
# 26419         No  Straight / Heterosexual          NaN        NaN
# 27229         No                      NaN  South Asian        Yes
# 35010        NaN                      NaN  South Asian        Yes
# 40151         No  Straight / Heterosexual  South Asian        Yes
# 40898         No  Straight / Heterosexual          NaN        NaN
# 42599         No  Straight / Heterosexual          NaN        Yes
# 43809        NaN                      NaN          NaN        Yes
# 50685         No  Straight / Heterosexual          NaN        NaN
# 60133        NaN                      NaN          NaN         No
# 63972         No  Straight / Heterosexual  South Asian        Yes
# 65988         No  Straight / Heterosexual          NaN        NaN
# 71874        NaN                      NaN          NaN        Yes
# 75103        NaN                      NaN          NaN         No
# 76822         No  Straight / Heterosexual  South Asian        Yes
# 77339        NaN                      NaN          NaN        NaN
# 79795         No  Straight / Heterosexual          NaN         No
# 83862         No  Straight / Heterosexual          NaN        Yes
# 84299        NaN                      NaN          NaN        NaN
# 86012         No                      NaN  South Asian        NaN
#
#                      SurveyLength                  SurveyEase
# Respondent
# 8           Appropriate in length  Neither easy nor difficult
# 10                       Too long                   Difficult
# 15                       Too long  Neither easy nor difficult
# 50                       Too long                        Easy
# 65          Appropriate in length  Neither easy nor difficult
# 68          Appropriate in length                        Easy
# 75                       Too long  Neither easy nor difficult
# 78          Appropriate in length                        Easy
# 83          Appropriate in length  Neither easy nor difficult
# 89                      Too short                        Easy
# 90          Appropriate in length                        Easy
# 99          Appropriate in length  Neither easy nor difficult
# 104         Appropriate in length                        Easy
# 121                      Too long  Neither easy nor difficult
# 124                      Too long                        Easy
# 140                      Too long                        Easy
# 169                      Too long  Neither easy nor difficult
# 174                      Too long  Neither easy nor difficult
# 176         Appropriate in length                        Easy
# 178                      Too long                        Easy
# 220         Appropriate in length                        Easy
# 238         Appropriate in length                        Easy
# 239                           NaN                         NaN
# 242         Appropriate in length  Neither easy nor difficult
# 263         Appropriate in length  Neither easy nor difficult
# 271                      Too long                        Easy
# 288                      Too long                        Easy
# 291                      Too long                        Easy
# 343                      Too long                        Easy
# 344         Appropriate in length  Neither easy nor difficult
# ...                           ...                         ...
# 88843       Appropriate in length                        Easy
# 88856                         NaN                         NaN
# 88869                    Too long  Neither easy nor difficult
# 88872                         NaN  Neither easy nor difficult
# 14444                   Too short  Neither easy nor difficult
# 20000                    Too long                         NaN
# 20567       Appropriate in length                        Easy
# 20892                    Too long                        Easy
# 21826       Appropriate in length                        Easy
# 24606                         NaN                         NaN
# 25114       Appropriate in length  Neither easy nor difficult
# 26419                    Too long  Neither easy nor difficult
# 27229                    Too long                        Easy
# 35010       Appropriate in length  Neither easy nor difficult
# 40151                    Too long  Neither easy nor difficult
# 40898       Appropriate in length                        Easy
# 42599                    Too long  Neither easy nor difficult
# 43809       Appropriate in length  Neither easy nor difficult
# 50685       Appropriate in length  Neither easy nor difficult
# 60133                    Too long  Neither easy nor difficult
# 63972       Appropriate in length  Neither easy nor difficult
# 65988       Appropriate in length                        Easy
# 71874                    Too long                        Easy
# 75103                    Too long                        Easy
# 76822                    Too long                        Easy
# 77339                         NaN                         NaN
# 79795                    Too long                   Difficult
# 83862                    Too long  Neither easy nor difficult
# 84299                         NaN                         NaN
# 86012       Appropriate in length                        Easy
#
# [9061 rows x 84 columns]

# %%
filt = df['Country'] == "India"
df.loc[filt]['SocialMedia'].value_counts()
# Out:
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# Hello                          5
# WeChat 微信                      5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: SocialMedia, dtype: int64

# %%
country_grp['SocialMedia'].value_counts().head(50)
# Out:
# Country              SocialMedia
# Afghanistan          Facebook                     15
#                      YouTube                       9
#                      I don't use social media      6
#                      WhatsApp                      4
#                      Instagram                     1
#                      LinkedIn                      1
#                      Twitter                       1
# Albania              WhatsApp                     18
#                      Facebook                     16
#                      Instagram                    13
#                      YouTube                      10
#                      Twitter                       8
#                      LinkedIn                      7
#                      Reddit                        6
#                      I don't use social media      4
#                      Snapchat                      1
#                      WeChat 微信                     1
# Algeria              YouTube                      42
#                      Facebook                     41
#                      Twitter                      14
#                      LinkedIn                      9
#                      I don't use social media      7
#                      Instagram                     7
#                      Reddit                        2
#                      WhatsApp                      2
# Andorra              Facebook                      2
#                      I don't use social media      2
#                      Reddit                        1
#                      Snapchat                      1
#                      YouTube                       1
# Angola               Twitter                       2
#                      Facebook                      1
#                      YouTube                       1
# Antigua and Barbuda  YouTube                       2
#                      Facebook                      1
#                      Instagram                     1
#                      Twitter                       1
#                      VK ВКонта́кте                 1
# Argentina            WhatsApp                    202
#                      Twitter                      80
#                      YouTube                      62
#                      Instagram                    53
#                      Reddit                       50
#                      Facebook                     45
#                      I don't use social media     22
#                      LinkedIn                     16
# Armenia              Facebook                     38
#                      YouTube                      23
#                      LinkedIn                      5
#                      Instagram                     3
# Name: SocialMedia, dtype: int64

# %%
country_grp['SocialMedia'].value_counts().loc['India']
# Out:
# SocialMedia
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# Hello                          5
# WeChat 微信                      5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: SocialMedia, dtype: int64

# %%
country_grp['SocialMedia'].value_counts().loc['United States']
# Out:
# SocialMedia
# Reddit                      5700
# Twitter                     3468
# Facebook                    2844
# YouTube                     2463
# I don't use social media    1851
# Instagram                   1652
# LinkedIn                    1020
# WhatsApp                     609
# Snapchat                     326
# WeChat 微信                     93
# VK ВКонта́кте                  9
# Weibo 新浪微博                     8
# Hello                          2
# Youku Tudou 优酷                 1
# Name: SocialMedia, dtype: int64

# %%
# country_grp['ConvertedComp'].median()
# Out:
# Country
# Afghanistan                                    6222.0
# Albania                                       10818.0
# Algeria                                        7878.0
# Andorra                                      160931.0
# Angola                                         7764.0
# Antigua and Barbuda                               NaN
# Argentina                                     17760.0
# Armenia                                       19692.0
# Australia                                     79783.0
# Austria                                       51559.0
# Azerbaijan                                    15858.0
# Bahamas                                           NaN
# Bahrain                                       15912.0
# Bangladesh                                     8764.0
# Barbados                                      21000.0
# Belarus                                       24000.0
# Belgium                                       48120.0
# Belize                                            NaN
# Benin                                             NaN
# Bhutan                                            NaN
# Bolivia                                       13020.0
# Bosnia and Herzegovina                        18360.0
# Botswana                                      38410.0
# Brazil                                        18036.0
# Brunei Darussalam                              6096.0
# Bulgaria                                      28080.0
# Burkina Faso                                   8388.0
# Burundi                                        3606.0
# Cambodia                                      10420.0
# Cameroon                                       6288.0
#                                                ...
# Sri Lanka                                      7476.0
# Sudan                                          2016.0
# Swaziland                                     62371.0
# Sweden                                        56004.0
# Switzerland                                   95440.0
# Syrian Arab Republic                           2742.0
# Taiwan                                        27954.0
# Tajikistan                                     4902.0
# Thailand                                      30672.0
# The former Yugoslav Republic of Macedonia     21996.0
# Timor-Leste                                  229500.0
# Togo                                           4188.0
# Tonga                                             NaN
# Trinidad and Tobago                           27828.0
# Tunisia                                        6468.0
# Turkey                                        17280.0
# Turkmenistan                                  27348.0
# Uganda                                         5490.0
# Ukraine                                       26940.0
# United Arab Emirates                          49008.0
# United Kingdom                                68041.0
# United Republic of Tanzania                    5192.0
# United States                                110000.0
# Uruguay                                       33850.0
# Uzbekistan                                     7176.0
# Venezuela, Bolivarian Republic of...           6384.0
# Viet Nam                                      11892.0
# Yemen                                         11940.0
# Zambia                                         5040.0
# Zimbabwe                                      19200.0
# Name: ConvertedComp, Length: 179, dtype: float64

# %%
country_grp['ConvertedComp'].median().loc['Germany']
# Out:
# 63016.0

# %%
# country_grp['ConvertedComp'].agg(['median', 'mean'])

# %%
country_grp['ConvertedComp'].agg(['median', 'mean']).loc['Canada']
# Out:
# median     68705.000000
# mean      134018.564909
# Name: Canada, dtype: float64

# %%
# filt = df['Country'] == 'India'
# df.loc[filt]['LanguageWorkedWith'].str.contains('Python')

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 3105

# %%
country_grp['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-cda55dd00399> in <module>
# ----> 1 country_grp['LanguageWorkedWith'].str.contains('Python').sum()
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     531             return self[attr]
#     532         if hasattr(self.obj, attr):
# --> 533             return self._make_wrapper(attr)
#     534
#     535         raise AttributeError("%r object has no attribute %r" %
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _make_wrapper(self, name)
#     568                    "using the 'apply' method".format(kind, name,
#     569                                                      type(self).__name__))
# --> 570             raise AttributeError(msg)
#     571
#     572         self._set_group_selection()
#
# AttributeError: Cannot access attribute 'str' of 'SeriesGroupBy' objects, try using the 'apply' method

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                                      8
# Albania                                         23
# Algeria                                         40
# Andorra                                          0
# Angola                                           2
# Antigua and Barbuda                              0
# Argentina                                      191
# Armenia                                         28
# Australia                                      790
# Austria                                        338
# Azerbaijan                                      17
# Bahamas                                          2
# Bahrain                                          4
# Bangladesh                                     204
# Barbados                                         1
# Belarus                                         69
# Belgium                                        296
# Belize                                           1
# Benin                                            3
# Bhutan                                           1
# Bolivia                                         11
# Bosnia and Herzegovina                          29
# Botswana                                         1
# Brazil                                         767
# Brunei Darussalam                                0
# Bulgaria                                       181
# Burkina Faso                                     0
# Burundi                                          1
# Cambodia                                         9
# Cameroon                                        16
#                                              ...
# Sri Lanka                                      137
# Sudan                                           16
# Swaziland                                        2
# Sweden                                         496
# Switzerland                                    460
# Syrian Arab Republic                             7
# Taiwan                                          88
# Tajikistan                                       0
# Thailand                                        92
# The former Yugoslav Republic of Macedonia        8
# Timor-Leste                                      1
# Togo                                             1
# Tonga                                            0
# Trinidad and Tobago                              5
# Tunisia                                         40
# Turkey                                         371
# Turkmenistan                                     6
# Uganda                                          47
# Ukraine                                        246
# United Arab Emirates                            49
# United Kingdom                                2384
# United Republic of Tanzania                     15
# United States                                10083
# Uruguay                                         36
# Uzbekistan                                      14
# Venezuela, Bolivarian Republic of...            28
# Viet Nam                                        78
# Yemen                                            3
# Zambia                                           4
# Zimbabwe                                        14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# United States                            20949
# India                                     9061
# Germany                                   5866
# United Kingdom                            5737
# Canada                                    3395
# France                                    2391
# Brazil                                    1948
# Poland                                    1922
# Australia                                 1903
# Netherlands                               1852
# Russian Federation                        1694
# Spain                                     1604
# Italy                                     1576
# Sweden                                    1274
# Switzerland                                978
# Israel                                     952
# Turkey                                     949
# Pakistan                                   923
# Ukraine                                    868
# Austria                                    839
# Czech Republic                             764
# Romania                                    760
# Iran                                       738
# Belgium                                    727
# China                                      664
# Bulgaria                                   659
# Mexico                                     642
# South Africa                               627
# Denmark                                    617
# Bangladesh                                 605
#                                          ...
# Liechtenstein                                3
# Democratic People's Republic of Korea        3
# Bahamas                                      3
# Guinea                                       3
# Cape Verde                                   3
# Mali                                         3
# Lesotho                                      3
# Barbados                                     3
# Belize                                       3
# Lao People's Democratic Republic             3
# Guyana                                       3
# Gabon                                        2
# Malawi                                       2
# Bhutan                                       2
# San Marino                                   2
# Seychelles                                   2
# Djibouti                                     2
# Sierra Leone                                 2
# Liberia                                      2
# Tonga                                        1
# Dominica                                     1
# Chad                                         1
# Papua New Guinea                             1
# Timor-Leste                                  1
# Sao Tome and Principe                        1
# Niger                                        1
# Saint Vincent and the Grenadines             1
# Brunei Darussalam                            1
# North Korea                                  1
# Saint Kitts and Nevis                        1
# Name: Country, Length: 179, dtype: int64

# %%
country_uses_python = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())

# %%
country_uses_python
# Out:
# Country
# Afghanistan                                      8
# Albania                                         23
# Algeria                                         40
# Andorra                                          0
# Angola                                           2
# Antigua and Barbuda                              0
# Argentina                                      191
# Armenia                                         28
# Australia                                      790
# Austria                                        338
# Azerbaijan                                      17
# Bahamas                                          2
# Bahrain                                          4
# Bangladesh                                     204
# Barbados                                         1
# Belarus                                         69
# Belgium                                        296
# Belize                                           1
# Benin                                            3
# Bhutan                                           1
# Bolivia                                         11
# Bosnia and Herzegovina                          29
# Botswana                                         1
# Brazil                                         767
# Brunei Darussalam                                0
# Bulgaria                                       181
# Burkina Faso                                     0
# Burundi                                          1
# Cambodia                                         9
# Cameroon                                        16
#                                              ...
# Sri Lanka                                      137
# Sudan                                           16
# Swaziland                                        2
# Sweden                                         496
# Switzerland                                    460
# Syrian Arab Republic                             7
# Taiwan                                          88
# Tajikistan                                       0
# Thailand                                        92
# The former Yugoslav Republic of Macedonia        8
# Timor-Leste                                      1
# Togo                                             1
# Tonga                                            0
# Trinidad and Tobago                              5
# Tunisia                                         40
# Turkey                                         371
# Turkmenistan                                     6
# Uganda                                          47
# Ukraine                                        246
# United Arab Emirates                            49
# United Kingdom                                2384
# United Republic of Tanzania                     15
# United States                                10083
# Uruguay                                         36
# Uzbekistan                                      14
# Venezuela, Bolivarian Republic of...            28
# Viet Nam                                        78
# Yemen                                            3
# Zambia                                           4
# Zimbabwe                                        14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
python_df = pd.concat([country_respondents, country_uses_python],axis = 'columns', sort = False)

# %%
python_df.head(10)
# Out:
#                 Country  LanguageWorkedWith
# United States     20949               10083
# India              9061                3105
# Germany            5866                2451
# United Kingdom     5737                2384
# Canada             3395                1558
# France             2391                1054
# Brazil             1948                 767
# Poland             1922                 751
# Australia          1903                 790
# Netherlands        1852                 767

# %%
python_df.rename(columns={'Country': 'NumRepondents', 'LanguageWorkedWith': 'NumKnowsPython'}, inplace=True)

# %%
python_df.head(10)
# Out:
#                 NumRepondents  NumKnowsPython
# United States           20949           10083
# India                    9061            3105
# Germany                  5866            2451
# United Kingdom           5737            2384
# Canada                   3395            1558
# France                   2391            1054
# Brazil                   1948             767
# Poland                   1922             751
# Australia                1903             790
# Netherlands              1852             767

# %%
python_df['PctKnowsPython'] = (python_df['NumKnowsPython']/python_df['NumRepondents']) * 100

# %%
python_df
# Out:
#                                        NumRepondents  NumKnowsPython  \
# United States                                  20949           10083
# India                                           9061            3105
# Germany                                         5866            2451
# United Kingdom                                  5737            2384
# Canada                                          3395            1558
# France                                          2391            1054
# Brazil                                          1948             767
# Poland                                          1922             751
# Australia                                       1903             790
# Netherlands                                     1852             767
# Russian Federation                              1694             708
# Spain                                           1604             641
# Italy                                           1576             625
# Sweden                                          1274             496
# Switzerland                                      978             460
# Israel                                           952             457
# Turkey                                           949             371
# Pakistan                                         923             251
# Ukraine                                          868             246
# Austria                                          839             338
# Czech Republic                                   764             285
# Romania                                          760             253
# Iran                                             738             268
# Belgium                                          727             296
# China                                            664             297
# Bulgaria                                         659             181
# Mexico                                           642             245
# South Africa                                     627             202
# Denmark                                          617             246
# Bangladesh                                       605             204
# ...                                              ...             ...
# Liechtenstein                                      3               1
# Democratic People's Republic of Korea              3               1
# Bahamas                                            3               2
# Guinea                                             3               2
# Cape Verde                                         3               0
# Mali                                               3               1
# Lesotho                                            3               1
# Barbados                                           3               1
# Belize                                             3               1
# Lao People's Democratic Republic                   3               0
# Guyana                                             3               2
# Gabon                                              2               0
# Malawi                                             2               0
# Bhutan                                             2               1
# San Marino                                         2               1
# Seychelles                                         2               1
# Djibouti                                           2               0
# Sierra Leone                                       2               1
# Liberia                                            2               0
# Tonga                                              1               0
# Dominica                                           1               1
# Chad                                               1               0
# Papua New Guinea                                   1               0
# Timor-Leste                                        1               1
# Sao Tome and Principe                              1               1
# Niger                                              1               1
# Saint Vincent and the Grenadines                   1               0
# Brunei Darussalam                                  1               0
# North Korea                                        1               0
# Saint Kitts and Nevis                              1               0
#
#                                        PctKnowsPython
# United States                               48.131176
# India                                       34.267741
# Germany                                     41.783157
# United Kingdom                              41.554820
# Canada                                      45.891016
# France                                      44.081974
# Brazil                                      39.373717
# Poland                                      39.073881
# Australia                                   41.513400
# Netherlands                                 41.414687
# Russian Federation                          41.794569
# Spain                                       39.962594
# Italy                                       39.657360
# Sweden                                      38.932496
# Switzerland                                 47.034765
# Israel                                      48.004202
# Turkey                                      39.093783
# Pakistan                                    27.193933
# Ukraine                                     28.341014
# Austria                                     40.286055
# Czech Republic                              37.303665
# Romania                                     33.289474
# Iran                                        36.314363
# Belgium                                     40.715268
# China                                       44.728916
# Bulgaria                                    27.465857
# Mexico                                      38.161994
# South Africa                                32.216906
# Denmark                                     39.870340
# Bangladesh                                  33.719008
# ...                                               ...
# Liechtenstein                               33.333333
# Democratic People's Republic of Korea       33.333333
# Bahamas                                     66.666667
# Guinea                                      66.666667
# Cape Verde                                   0.000000
# Mali                                        33.333333
# Lesotho                                     33.333333
# Barbados                                    33.333333
# Belize                                      33.333333
# Lao People's Democratic Republic             0.000000
# Guyana                                      66.666667
# Gabon                                        0.000000
# Malawi                                       0.000000
# Bhutan                                      50.000000
# San Marino                                  50.000000
# Seychelles                                  50.000000
# Djibouti                                     0.000000
# Sierra Leone                                50.000000
# Liberia                                      0.000000
# Tonga                                        0.000000
# Dominica                                   100.000000
# Chad                                         0.000000
# Papua New Guinea                             0.000000
# Timor-Leste                                100.000000
# Sao Tome and Principe                      100.000000
# Niger                                      100.000000
# Saint Vincent and the Grenadines             0.000000
# Brunei Darussalam                            0.000000
# North Korea                                  0.000000
# Saint Kitts and Nevis                        0.000000
#
# [179 rows x 3 columns]

# %%
python_df.sort_values(by='PctKnowsPython', ascending=False, inplace=True)

# %%
python_df.head(15)
# Out:
#                            NumRepondents  NumKnowsPython  PctKnowsPython
# Dominica                               1               1      100.000000
# Niger                                  1               1      100.000000
# Sao Tome and Principe                  1               1      100.000000
# Timor-Leste                            1               1      100.000000
# Turkmenistan                           7               6       85.714286
# Mauritania                             7               5       71.428571
# Guyana                                 3               2       66.666667
# Bahamas                                3               2       66.666667
# Guinea                                 3               2       66.666667
# Uganda                                72              47       65.277778
# Iceland                               49              30       61.224490
# Namibia                                5               3       60.000000
# Benin                                  5               3       60.000000
# Haiti                                  5               3       60.000000
# Congo, Republic of the...              7               4       57.142857

# %%
python_df.loc['Japan']
# Out:
# NumRepondents     391.000000
# NumKnowsPython    182.000000
# PctKnowsPython     46.547315
# Name: Japan, dtype: float64
